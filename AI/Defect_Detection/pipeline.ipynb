# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 23.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### 순차적 파이프라인

# %% [markdown]
# 모델 순차적용
#
# 구현 간단
#
# 이전 모델 오류 다음 모델에 영향

# %% [markdown]
# ### 병렬적 파이프라인

# %% [markdown]
# Input 이미지 모든 모델 동시 적용
#
# 각 모델이 독립적으로 결함 유형 탐지
#
# 속도  빠름
#
# 리소스 사용량 많음

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09ffed60-fdf9-4630-9e4c-9901e9097329.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09ffed60-fdf9-4630-9e4c-9901e9097329.jpg: 384x640 (no detections), 89.5ms
# Speed: 2.3ms preprocess, 89.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09ffed60-fdf9-4630-9e4c-9901e9097329.jpg: 384x640 (no detections), 46.9ms
# Speed: 2.1ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09ffed60-fdf9-4630-9e4c-9901e9097329.jpg: 384x640 (no detections), 34.7ms
# Speed: 2.1ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09ffed60-fdf9-4630-9e4c-9901e9097329.jpg: 384x640 (no detections), 22.4ms
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09fd6dae-74c6-4474-87a0-0b2e8f9882d3.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09fd6dae-74c6-4474-87a0-0b2e8f9882d3.jpg: 384x640 (no detections), 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09fd6dae-74c6-4474-87a0-0b2e8f9882d3.jpg: 384x640 (no detections), 32.0ms
# Speed: 2.6ms preprocess, 32.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09fd6dae-74c6-4474-87a0-0b2e8f9882d3.jpg: 384x640 (no detections), 23.8ms
# Speed: 2.8ms preprocess, 23.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/CoatingDamage/datasets/jpg/202_09fd6dae-74c6-4474-87a0-0b2e8f9882d3.jpg: 384x640 (no detections), 23.5ms
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/data/Steel/SteelDamage/dataset/images/train/201_8a6a54e4-51a4-4457-8445-2097e1818faf.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/SteelDamage/dataset/images/train/201_8a6a54e4-51a4-4457-8445-2097e1818faf.jpg: 384x640 (no detections), 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/SteelDamage/dataset/images/train/201_8a6a54e4-51a4-4457-8445-2097e1818faf.jpg: 384x640 (no detections), 31.6ms
# Speed: 4.4ms preprocess, 31.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/SteelDamage/dataset/images/train/201_8a6a54e4-51a4-4457-8445-2097e1818faf.jpg: 384x640 (no detections), 24.9ms
# Speed: 2.8ms preprocess, 24.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/data/Steel/SteelDamage/dataset/images/train/201_8a6a54e4-51a4-4457-8445-2097e1818faf.jpg: 384x640 (no detections), 24.8ms
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt.jpg: 480x640 (no detections), 11.1ms
# Speed: 4.5ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt.jpg: 480x640 2 crack_1s, 1 crack_2, 34.7ms
# Speed: 3.9ms preprocess, 34.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt.jpg: 480x640 (no detections), 25.6ms
# Speed: 2.8ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt.jpg: 480x640 (no detections), 39.0ms
# Speed: 9.8ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt.jpg: 480x640 (no detections), 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt2.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt2.jpg: 640x480 (no detections), 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt2.jpg: 640x480 (no detections), 34.6ms
# Speed: 2.4ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt2.jpg: 640x480 (no detections), 25.2ms
# Speed: 2.7ms preprocess, 25.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt2.jpg: 640x480 (no detections), 25.2ms
# Speed: 2.6ms preprocess, 25.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt2.jpg: 640x480 (no detections), 11.8ms
# Speed: 3.0ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt3.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt3.jpg: 640x480 (no detections), 10.6ms
# Speed: 4.5ms preprocess, 10.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt3.jpg: 640x480 (no detections), 34.7ms
# Speed: 4.1ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt3.jpg: 640x480 (no detections), 26.0ms
# Speed: 4.3ms preprocess, 26.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt3.jpg: 640x480 (no detections), 26.1ms
# Speed: 4.2ms preprocess, 26.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt3.jpg: 640x480 (no detections), 14.8ms
# Speed: 4.2ms preprocess, 14.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt4.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt4.jpg: 640x480 (no detections), 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt4.jpg: 640x480 (no detections), 34.5ms
# Speed: 2.6ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt4.jpg: 640x480 (no detections), 25.2ms
# Speed: 2.6ms preprocess, 25.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt4.jpg: 640x480 (no detections), 25.5ms
# Speed: 2.5ms preprocess, 25.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt4.jpg: 640x480 (no detections), 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt5.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt5.jpg: 640x480 (no detections), 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt5.jpg: 640x480 (no detections), 34.7ms
# Speed: 3.9ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt5.jpg: 640x480 1 Exposure, 28.3ms
# Speed: 4.3ms preprocess, 28.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt5.jpg: 640x480 (no detections), 28.2ms
# Speed: 2.5ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt5.jpg: 640x480 (no detections), 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt6.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt6.jpg: 640x480 (no detections), 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt6.jpg: 640x480 (no detections), 34.5ms
# Speed: 2.4ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt6.jpg: 640x480 1 Exposure, 24.8ms
# Speed: 2.5ms preprocess, 24.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt6.jpg: 640x480 1 SteelDefect_Level_3, 24.8ms
# Speed: 2.5ms preprocess, 24.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt6.jpg: 640x480 (no detections), 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/tt7.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/tt7.jpg: 640x480 (no detections), 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt7.jpg: 640x480 (no detections), 34.7ms
# Speed: 2.7ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt7.jpg: 640x480 (no detections), 24.9ms
# Speed: 2.6ms preprocess, 24.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt7.jpg: 640x480 (no detections), 24.8ms
# Speed: 2.5ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/tt7.jpg: 640x480 (no detections), 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt8.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt8.jpg: 640x480 (no detections), 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt8.jpg: 640x480 1 crack_1, 34.4ms
# Speed: 2.1ms preprocess, 34.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt8.jpg: 640x480 (no detections), 24.8ms
# Speed: 2.1ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt8.jpg: 640x480 (no detections), 24.7ms
# Speed: 2.1ms preprocess, 24.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt8.jpg: 640x480 (no detections), 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt9.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt9.jpg: 416x640 (no detections), 54.9ms
# Speed: 3.0ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt9.jpg: 416x640 (no detections), 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt9.jpg: 416x640 (no detections), 50.1ms
# Speed: 2.6ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt9.jpg: 416x640 (no detections), 26.7ms
# Speed: 2.7ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt9.jpg: 416x640 (no detections), 46.2ms
# Speed: 2.7ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt10.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt10.jpg: 480x640 (no detections), 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt10.jpg: 480x640 (no detections), 34.5ms
# Speed: 2.0ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt10.jpg: 480x640 (no detections), 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt10.jpg: 480x640 (no detections), 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt10.jpg: 480x640 (no detections), 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt11.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt11.jpg: 480x640 (no detections), 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt11.jpg: 480x640 (no detections), 34.6ms
# Speed: 2.7ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt11.jpg: 480x640 (no detections), 25.5ms
# Speed: 1.8ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt11.jpg: 480x640 (no detections), 25.8ms
# Speed: 1.9ms preprocess, 25.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt11.jpg: 480x640 (no detections), 15.0ms
# Speed: 2.9ms preprocess, 15.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt12.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt12.jpg: 448x640 (no detections), 55.3ms
# Speed: 3.2ms preprocess, 55.3ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt12.jpg: 448x640 (no detections), 83.7ms
# Speed: 2.6ms preprocess, 83.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt12.jpg: 448x640 (no detections), 36.3ms
# Speed: 2.3ms preprocess, 36.3ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt12.jpg: 448x640 (no detections), 26.6ms
# Speed: 1.9ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt12.jpg: 448x640 (no detections), 25.6ms
# Speed: 1.8ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt13.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt13.jpg: 384x640 (no detections), 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt13.jpg: 384x640 (no detections), 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt13.jpg: 384x640 (no detections), 24.2ms
# Speed: 2.2ms preprocess, 24.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt13.jpg: 384x640 (no detections), 24.2ms
# Speed: 2.1ms preprocess, 24.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt13.jpg: 384x640 (no detections), 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt14.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt14.jpg: 448x640 (no detections), 14.4ms
# Speed: 6.0ms preprocess, 14.4ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt14.jpg: 448x640 (no detections), 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt14.jpg: 448x640 (no detections), 25.8ms
# Speed: 2.6ms preprocess, 25.8ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt14.jpg: 448x640 (no detections), 25.7ms
# Speed: 1.9ms preprocess, 25.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt14.jpg: 448x640 (no detections), 12.2ms
# Speed: 2.7ms preprocess, 12.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt15.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt15.jpg: 640x640 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt15.jpg: 640x640 (no detections), 44.6ms
# Speed: 2.3ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt15.jpg: 640x640 (no detections), 29.0ms
# Speed: 2.8ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt15.jpg: 640x640 (no detections), 28.9ms
# Speed: 2.7ms preprocess, 28.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt15.jpg: 640x640 (no detections), 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt16.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt16.jpg: 480x640 (no detections), 9.2ms
# Speed: 3.9ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt16.jpg: 480x640 (no detections), 34.5ms
# Speed: 1.9ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt16.jpg: 480x640 (no detections), 25.5ms
# Speed: 1.9ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt16.jpg: 480x640 (no detections), 25.4ms
# Speed: 1.9ms preprocess, 25.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt16.jpg: 480x640 (no detections), 14.1ms
# Speed: 2.8ms preprocess, 14.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt17.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt17.jpg: 480x640 (no detections), 6.8ms
# Speed: 3.2ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt17.jpg: 480x640 (no detections), 34.7ms
# Speed: 2.7ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt17.jpg: 480x640 (no detections), 25.5ms
# Speed: 1.8ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt17.jpg: 480x640 (no detections), 25.6ms
# Speed: 1.9ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt17.jpg: 480x640 (no detections), 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt18.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt18.jpg: 416x640 (no detections), 19.5ms
# Speed: 6.3ms preprocess, 19.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt18.jpg: 416x640 (no detections), 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt18.jpg: 416x640 (no detections), 24.8ms
# Speed: 2.4ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt18.jpg: 416x640 (no detections), 25.2ms
# Speed: 1.8ms preprocess, 25.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt18.jpg: 416x640 (no detections), 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt19.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt19.jpg: 640x480 1 PaintDamage, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt19.jpg: 640x480 (no detections), 34.7ms
# Speed: 2.6ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt19.jpg: 640x480 (no detections), 25.7ms
# Speed: 2.5ms preprocess, 25.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt19.jpg: 640x480 (no detections), 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt19.jpg: 640x480 (no detections), 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt20.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt20.jpg: 640x480 (no detections), 9.1ms
# Speed: 4.3ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt20.jpg: 640x480 (no detections), 34.7ms
# Speed: 4.2ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt20.jpg: 640x480 (no detections), 25.8ms
# Speed: 4.2ms preprocess, 25.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt20.jpg: 640x480 (no detections), 26.1ms
# Speed: 4.2ms preprocess, 26.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt20.jpg: 640x480 (no detections), 11.2ms
# Speed: 4.2ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt21.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt21.jpg: 640x480 (no detections), 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt21.jpg: 640x480 1 crack_2, 35.0ms
# Speed: 2.6ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt21.jpg: 640x480 (no detections), 28.2ms
# Speed: 2.5ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt21.jpg: 640x480 (no detections), 28.5ms
# Speed: 4.2ms preprocess, 28.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt21.jpg: 640x480 (no detections), 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt22.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt22.jpg: 640x480 (no detections), 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt22.jpg: 640x480 (no detections), 34.4ms
# Speed: 2.4ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt22.jpg: 640x480 (no detections), 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt22.jpg: 640x480 (no detections), 24.8ms
# Speed: 2.6ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt22.jpg: 640x480 (no detections), 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt23.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt23.jpg: 640x480 (no detections), 7.3ms
# Speed: 2.9ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt23.jpg: 640x480 (no detections), 34.5ms
# Speed: 2.5ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt23.jpg: 640x480 (no detections), 24.8ms
# Speed: 2.7ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt23.jpg: 640x480 (no detections), 25.4ms
# Speed: 4.0ms preprocess, 25.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt23.jpg: 640x480 (no detections), 11.8ms
# Speed: 4.0ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt24.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt24.jpg: 640x480 (no detections), 12.8ms
# Speed: 4.2ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt24.jpg: 640x480 (no detections), 34.7ms
# Speed: 2.5ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt24.jpg: 640x480 (no detections), 26.8ms
# Speed: 4.0ms preprocess, 26.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt24.jpg: 640x480 (no detections), 28.8ms
# Speed: 2.5ms preprocess, 28.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt24.jpg: 640x480 (no detections), 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt25.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt25.jpg: 640x480 (no detections), 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt25.jpg: 640x480 1 crack_1, 1 crack_2, 34.5ms
# Speed: 2.7ms preprocess, 34.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt25.jpg: 640x480 (no detections), 28.3ms
# Speed: 2.8ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt25.jpg: 640x480 (no detections), 28.5ms
# Speed: 2.5ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt25.jpg: 640x480 2 Efflorescence_Level1s, 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt26.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt26.jpg: 640x480 (no detections), 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt26.jpg: 640x480 (no detections), 34.5ms
# Speed: 2.6ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt26.jpg: 640x480 (no detections), 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt26.jpg: 640x480 (no detections), 25.1ms
# Speed: 2.5ms preprocess, 25.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt26.jpg: 640x480 (no detections), 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
from ultralytics import YOLO

# 6개의 모델 로드
model_paths = [
    '/content/drive/MyDrive/Homeplus/model/CoatingDamage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/crack_best.pt',
    '/content/drive/MyDrive/Homeplus/model/exposed_best.pt',
    '/content/drive/MyDrive/Homeplus/model/steel_best.pt',
    '/content/drive/MyDrive/Homeplus/model/efflorescence_waterLeakage_best.pt',
    '/content/drive/MyDrive/Homeplus/model/spalling_best.pt',
]
models = [YOLO(path) for path in model_paths]

def detect_defects(image_path):
  """
  이미지에서 6가지 결함 유형을 탐지하는 함수

  Args:
    image_path: 이미지 파일 경로

  Returns:
    results: 모든 모델의 예측 결과를 포함하는 리스트
  """
  results = []
  for model in models:
    result = model(image_path)  # 이미지 예측
    results.append(result)
  return results

# 이미지 예측
image_path = '/content/drive/MyDrive/Homeplus/test/tt27.jpg'
results = detect_defects(image_path)

# 결과 처리 (각 모델의 결과를 종합)
# ...
# Out:
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt27.jpg: 640x480 (no detections), 11.6ms
# Speed: 4.7ms preprocess, 11.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt27.jpg: 640x480 (no detections), 34.7ms
# Speed: 4.3ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt27.jpg: 640x480 1 Exposure, 28.5ms
# Speed: 4.1ms preprocess, 28.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt27.jpg: 640x480 (no detections), 28.6ms
# Speed: 4.1ms preprocess, 28.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/Homeplus/test/tt27.jpg: 640x480 1 Efflorescence_Level1, 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %% [markdown]
# ### 계층적 파이프라인

# %% [markdown]
# 콘크리트
# *   균열(크랙, 금 등)
# *   박리(표면 들뜸, 깨짐, 떨어짐 등)
# *   백태/누수(흰색 흔적, 물 자국 등)
# *   철근 노출(녹슨 철근 등)
#
#
#
# 강재
# *   강재 손상(크랙, 금, 찢어짐 등)
# *   도장 손상(페인트 손상, 들뜸, 떨어짐 등)

# %% [markdown]
# ### 앙상블 파이프라인

# %% [markdown]
# 각 모델 예측 결과 결합하여 최종 예측 결과 생성
#
# 약점 보완 -> 성능 향상
#
# 방법에 따른 복잡도 증가
#
# 개별 모델 성능 좋아야 해서 일단 보류
